# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika-bindhu/FMML_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 16:15:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   113MB/s    in 0.6s
#
# 2024-03-31 16:15:24 (113 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10502   1205.1245v2  The sparse group lasso optimization problem is...  stat
# 9465    1106.4632v1  Given a point cloud, we consider inferring kin...    cs
# 2108    1407.2483v2  Learning Markov blanket (MB) structures has pr...  stat
# 6660   1704.08792v1  In deep learning, performance is strongly affe...  stat
# 18178  cs/0506031v1  Automatic or assisted workflow composition is ...    cs
# ...             ...                                                ...   ...
# 33565   1211.4866v1  Data mining techniques have been used by resea...    cs
# 26078  1608.05477v2  We propose a novel recurrent encoder-decoder n...    cs
# 22677  1704.02162v2  Super-resolution is a classical problem in ima...  stat
# 39253  1504.07967v1  The most frequently employed measure for perfo...    cs
# 19627   1210.4857v1  This paper provides some new guidance in the c...    cs
#
#                                                    title  year  \
# 10502  Sparse group lasso and high dimensional multin...  2012
# 9465   Inferring 3D Articulated Models for Box Packag...  2011
# 2108                  Counting Markov Blanket Structures  2014
# 6660   DeepArchitect: Automatically Designing and Tra...  2017
# 18178  A Constrained Object Model for Configuration B...  2005
# ...                                                  ...   ...
# 33565  A Brief Review of Data Mining Application Invo...  2012
# 26078  A Recurrent Encoder-Decoder Network for Sequen...  2016
# 22677  Locally-adapted convolution-based super-resolu...  2017
# 39253  Improved repeatability measures for evaluating...  2015
# 19627  Generalized Belief Propagation on Tree Robust ...  2012
#
#                                                 keywords
# 10502  [optimization, coordinate, algorithm, algorith...
# 9465   [inferring, kinematic, articulated, manipulati...
# 2108   [structures, performing, selection, discoverin...
# 6660   [performance, architecture, hyperparameters, e...
# 18178  [automatic, composition, applications, composi...
# ...                                                  ...
# 33565  [techniques, researchers, analyzing, sequences...
# 26078  [recurrent, alignment, regularized, regression...
# 22677  [resolution, classical, processing, applicatio...
# 39253  [frequently, performance, characterisation, de...
# 19627  [construction, generalized, propagation, loops...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10502    [optimization, coordinate, algorithm, algorith...
# 9465     [inferring, kinematic, articulated, manipulati...
# 2108     [structures, performing, selection, discoverin...
# 6660     [performance, architecture, hyperparameters, e...
# 18178    [automatic, composition, applications, composi...
#                                ...
# 17351    [classifiers, convolutional, challenge, sentim...
# 38007    [technique, weighting, technique, coopetitive,...
# 22687    [equivalent, variational, approximation, isotr...
# 15950    [discriminative, translation, utilizing, stati...
# 14038    [determining, activation, trajectories, accomp...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aab19175-52fd-45d4-9c93-65a1c342089f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aab19175-52fd-45d4-9c93-65a1c342089f")) {                    Plotly.newPlot(                        "aab19175-52fd-45d4-9c93-65a1c342089f",                        [{"x":["outperforms","functions","established","classifier","classification","implementation","performance","parameters","estimating","dimensional","multinomial","applicable","available","coordinate","implemented","investigate","including","algorithm","considered","magnitude","convergence","different","optimization","manipulating","configurations","dependencies","neighboring","inferring","structure","conditional","successfully","articulated","represented","kinematic","variables","exponentially","performing","efficiently","quantitatively","determining","selection","discovering","structures","relationships","particular","framework","outperform","discovery","experiments","sequential","therefore","algorithms","intuition","effectively","comparing","designing","introduce","compactly","represent","extensive","extensible","expressive","competitive","hyperparameters","structured","computational","unexplored","architectures","hyperparameter","automatic","resulting","architecture","automatically","specification","configuration","viability","languages","techniques","metamodels","composite","generally","constrained","composition","traditionally","addressed","applications","intraoperative","possibility","importance","diffusion","contribution","necessary","knowledge","corticospinal","similarity","interventions","estimation","neurological","evaluation","comparison","anatomical","preoperative","coefficient","segmentation","candidates","likelihood","evolution","regulation","statistical","circuitry","communication","extension","represents","demonstration","properties","exponential","hypothesis","understanding","specifically","benchmark","description","representation","respectively","associated","dimensions","extending","recognition","efficient","experiment","important","evaluated","refinement","adaptation","computation","distribution","prototype","posterior","maintains","approximation","generalize","continuous","efficiency","inference","researchers","variational","hierarchical","distributions","activations","attracted","alternative","essential","attention","standards","generalized","identification","decorrelation","retrieval","embedding","triangulation","discriminative","volumetric","information","iterative","accurately","registration","cluttered","candidate","dependency","leveraged","histogram","occlusion","extracted","introduced","iteratively","delineating","discriminating","impairment","progression","sensitive","cognitively","structural","extraction","investigations","alzheimers","cognitive","advantage","biomarkers","investigated","discriminant","especially","challenging","demonstrated","specificity","assessing","diagnosis","modalities","practical","approaches","effective","significantly"],"y":[262,206,58,163,489,145,899,237,70,204,6,55,294,27,90,139,222,789,119,67,109,718,325,6,29,44,14,26,321,86,70,7,78,4,132,18,80,156,24,37,161,22,128,70,256,539,85,61,612,60,137,582,23,119,72,37,366,3,113,153,5,32,109,12,98,289,8,110,14,181,149,225,171,25,38,5,97,386,2,11,74,66,30,26,38,436,3,41,81,21,65,79,357,1,143,3,177,3,246,122,9,3,17,191,23,54,60,2,165,1,66,76,36,6,219,47,55,163,160,196,73,381,90,109,36,36,393,403,72,336,136,25,50,141,227,21,45,17,109,51,97,146,211,70,49,109,117,19,29,83,79,159,9,75,95,1,99,117,5,95,14,712,85,81,28,13,49,34,8,22,28,112,137,29,1,5,1,1,54,1,69,132,10,3,48,99,4,44,16,106,236,92,7,15,48,36,149,442,245,241],"type":"bar"},{"x":["outperforms","functions","established","cl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>SemTK</span> <span style=''>An</span> <span style=''>Ontology</span> <span style=''>first</span> <span style=''>Open</span> <span style=''>Source</span> <span style=''>Semantic</span> <span style=''>Toolkit</span> <span style=''>for</span> <span style=''>Managing</span> <span style=''>and</span> <span style=''>Querying</span> <span style='background-color:rgba(0, 255, 0, 0.3522727272727273);'>Knowledge</span> <span style=''>Graphs</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>recent</span> <span style=''>adoption</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3522727272727273);'>Knowledge</span> <span style=''>Graphs</span> <span style=''>as</span> <span style=''>an</span> <span style=''>enabling</span> <span style='background-color:rgba(0, 255, 0, 0.6615384615384615);'>technology</span> <span style=''>in</span> <span style=''>multiple</span> <span style=''>high</span> <span style=''>profile</span> <span style='background-color:rgba(0, 255, 0, 0.4371859296482411);'>artificial</span> <span style='background-color:rgba(0, 255, 0, 0.7586206896551724);'>intelligence</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5737704918032787);'>cognitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>has</span> <span style=''>led</span> <span style=''>to</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style='background-color:rgba(0, 255, 0, 0.6615384615384615);'>technology</span> <span style=''>stack</span> <span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.9238095238095239);'>semantics</span> <span style=''>related</span> <span style=''>tools</span> <span style=''>however</span> <span style=''>are</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>serving</span> <span style=''>experts</span> <span style=''>with</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3198380566801621);'>understanding</span> <span style=''>of</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.631578947368421);'>technologies</span> <span style=''>For</span> <span style=''>example</span> <span style=''>triplification</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>but</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style=''>open</span> <span style=''>source</span> <span style=''>tool</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unfamiliar</span> <span style=''>with</span> <span style=''>OWLRDF</span> <span style=''>to</span> <span style=''>import</span> <span style=''>data</span> <span style=''>into</span> <span style=''>a</span> <span style=''>semantic</span> <span style=''>triple</span> <span style=''>store</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>manner</span> <span style=''>Further</span> <span style=''>many</span> <span style=''>tools</span> <span style=''>require</span> <span style=''>users</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style=''>working</span> <span style='background-color:rgba(0, 255, 0, 0.3198380566801621);'>understanding</span> <span style=''>of</span> <span style=''>SPARQL</span> <span style=''>to</span> <span style=''>query</span> <span style=''>data</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Splitting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GANs)</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>better</span> <span style=''>quality</span> <span style=''>samples</span> <span style=''>when</span> <span style=''>class</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>ie</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>GAN</span> <span style=''>setup</span> <span style=''>This</span> <span style=''>is</span> <span style=''>still</span> <span style=''>observed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>GAN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stabilized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style=''>and</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>high</span> <span style=''>capacity</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>such</span> <span style=''>as</span> <span style=''>ResNet</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>boost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>GAN</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmenting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>The</span> <span style=''>new</span> <span style=''>classes</span> <span style=''>come</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>space</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>same</span> <span style=''>GAN</span> <span style=''>model</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>also</span> <span style=''>feasible</span> <span style=''>when</span> <span style=''>no</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>ie</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>setup</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>samples</span> <span style=''>reach</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgb ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimistic</span> <span style=''>Rates</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Smooth</span> <span style=''>Loss</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>an</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>O(H</span> <span style=''>R</span> <span style=''>n2</span> <span style=''>R</span> <span style=''>n</span> <span style=''>sqrtH</span> <span style=''>L)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>an</span> <span style=''>H</span> <span style=''>smooth</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.7777777777777777);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>R</span> <span style=''>n</span> <span style=''>where</span> <span style=''>L</span> <span style=''>is</span> <span style=''>the</span> <span style=''>best</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achievable</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>For</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>classes</span> <span style=''>where</span> <span style=''>R</span> <span style=''>n</span> <span style=''>sqrtRn</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>translates</span> <span style=''>to</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>O(RHn)</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>(L0)</span> <span style=''>case</span> <span style=''>and</span> <span style=''>O(RHn</span> <span style=''>sqrtL</span> <span style=''>RHn)</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>online</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3749999999999999);'>stochastic</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>a</span> <span style=''>smooth</span> <span style=''>non</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimistic</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>Least</span> <span style=''>Squares</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>self</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>soft</span> <span style=''>label</span> <span style=''>and</span> <span style=''>a</span> <span style=''>hard</span> <span style=''>label</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>self</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>be</span> <span style=''>derived</span> <span style=''>by</span> <span style=''>applying</span> <span style=''>block</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>to</span> <span style=''>two</span> <span style=''>related</span> <span style=''>but</span> <span style=''>slightly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>soft</span> <span style=''>label</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>related</span> <span style=''>to</span> <span style=''>an</span> <span style=''>idea</span> <span style=''>about</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>that</span> <span style=''>dates</span> <span style=''>back</span> <span style=''>to</span> <span style=''>the</span> <span style=''>1930s</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>soft</span> <span style=''>label</span> <span style=''>variant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>the</span> <span style=''>hard</span> <span style=''>label</span> <span style=''>variant</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>explain</span> <span style=''>this</span> <span style='background-color:rgba( ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08041458184417441)
# 	knowledge (0.12759113652609005)
# 	processing (0.10400285918513223)
# 	segmentation (0.06826304503216583)
# 	representation (0.136168691922802)
# 	detection (0.11186561829878484)
# 	information (0.2544674767691208)
# 	different (0.2566118656182988)
# 	convolutional (0.13724088634739098)
# 	recognition (0.14045746962115796)
#
# Some Statistics words are:
# 	variables (0.13236763236763235)
# 	theoretical (0.14235764235764237)
# 	statistical (0.15484515484515485)
# 	stochastic (0.14285714285714285)
# 	distribution (0.17882117882117882)
# 	algorithm (0.3886113886113886)
# 	estimation (0.17082917082917082)
# 	dimensional (0.18831168831168832)
# 	inference (0.2022977022977023)
# 	regression (0.18081918081918083)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16fb978d-cf68-43ac-b0af-9cb73f4e60aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16fb978d-cf68-43ac-b0af-9cb73f4e60aa")) {                    Plotly.newPlot(                        "16fb978d-cf68-43ac-b0af-9cb73f4e60aa",                        [{"x":["outperforms","functions","established","classifier","classification","implementation","performance","parameters","estimating","dimensional","multinomial","applicable","available","coordinate","implemented","investigate","including","algorithm","considered","magnitude","convergence","different","optimization","manipulating","configurations","dependencies","neighboring","inferring","structure","conditional","successfully","articulated","represented","kinematic","variables","exponentially","performing","efficiently","quantitatively","determining","selection","discovering","structures","relationships","particular","framework","outperform","discovery","experiments","sequential","therefore","algorithms","intuition","effectively","comparing","designing","introduce","compactly","represent","extensive","extensible","expressive","competitive","hyperparameters","structured","computational","unexplored","architectures","hyperparameter","automatic","resulting","architecture","automatically","specification","configuration","viability","languages","techniques","metamodels","composite","generally","constrained","composition","traditionally","addressed","applications","intraoperative","possibility","importance","diffusion","contribution","necessary","knowledge","corticospinal","similarity","interventions","estimation","neurological","evaluation","comparison","anatomical","preoperative","coefficient","segmentation","candidates","likelihood","evolution","regulation","statistical","circuitry","communication","extension","represents","demonstration","properties","exponential","hypothesis","understanding","specifically","benchmark","description","representation","respectively","associated","dimensions","extending","recognition","efficient","experiment","important","evaluated","refinement","adaptation","computation","distribution","prototype","posterior","maintains","approximation","generalize","continuous","efficiency","inference","researchers","variational","hierarchical","distributions","activations","attracted","alternative","essential","attention","standards","generalized","identification","decorrelation","retrieval","embedding","triangulation","discriminative","volumetric","information","iterative","accurately","registration","cluttered","candidate","dependency","leveraged","histogram","occlusion","extracted","introduced","iteratively","delineating","discriminating","impairment","progression","sensitive","cognitively","structural","extraction","investigations","alzheimers","cognitive","advantage","biomarkers","investigated","discriminant","especially","challenging","demonstrated","specificity","assessing","diagnosis","modalities","practical","approaches","effective","significantly","sensitivity","identifying","inspiration","individual","interested","organization","potentially","demonstrate","collections","historians","generalizations","stochastic","deterministic","equivalent","implementations","environments","partially","theoretical","processes","observable","procedural","reinforcement","restricted","prioritized","divergence","approximate","tradeoffs","approximations","motivating","interpolates","application","headlines","scientific","otherwise","collective","contributions","perspectives","criterion","occurrences","questions","perspective","discourse","citations","diversity","clustering","microblogs","methodologies","summarized","scenarios","comprehensive","navigation","instruction", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	propensity
# 	bernstein
# 	unsuccessful
# 	thermostats
# 	replicated
# 	misspecified
# 	nonparametrics
# 	penalizations
# 	majorization
# 	administrative
# 	administration
# 	sustainability
# 	tibshirani
# 	epanechnikov
# 	barycenter
# 	conformal
# 	syndromes
# 	stabilisation
# 	depression
# 	depressive
# Some words which never appear in Statistics papers:
# 	articulated
# 	metamodels
# 	preoperative
# 	historians
# 	procedural
# 	headlines
# 	discourse
# 	microblogs
# 	instruction
# 	accompany
# 	executions
# 	milestone
# 	untrimmed
# 	synchronized
# 	elaborated
# 	deductive
# 	artefacts
# 	undertake
# 	resurgence
# 	meteorological

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072385400024579e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
